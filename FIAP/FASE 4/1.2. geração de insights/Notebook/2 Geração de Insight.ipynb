# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Análise de Negócios
# ### Preços dos combustíveis ofertados nos postos

# %% [markdown]
# <img src = 'preco_combustivel.jpeg'>

# %% [markdown]
# ### Fomos contratados por uma Petroleira para construir uma análise de negócios para entender a dinâmica de preços que está sendo ofertado pelos postos.
# 1 - Teremos que trabalhar com Dados Existentes <br/>
# link: https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis <br/>
# <img src = 'anp.png'><br/>
# <br/>
# Como foi uma solicitação do nosso cliente, teremos que avaliar os ultimos 5 anos da base de dados.<br/>
# <img src = 'tabela_base_dados.png'><br/>
#
# <br/>
# Quando abrimos as tabelas nos deparamos que cada semestre possui uma quantidade muito grande de dados, logo juntas 5 anos (10 tabelas) fica difícil!<br/>
# <br/>
# Como muitas das vezes não temos o Engenheiro de Dados, temos que dar os nossos pulos!<br/>

# %% [markdown]
# 2 - Armazenar esses dados em um banco de dados <br/>
# <img src = 'PostgreSQL-logo.png'><br/>
# <img src = 'postgre1.png'><br/>

# %%
"""
CREATE TABLE anp.preco_combustivel(
		regiao 				varchar(255)
		,estado				varchar(255)
		,municipio			varchar(255)
		,revenda			varchar(255)
		,cnpj				varchar(255)
		,nome_rua			varchar(255)	
		,numero_rua			varchar(255)
		,complemento		varchar(255)
		,bairro				varchar(255)
		,cep				varchar(255)
		,produto			varchar(255)
		,data_coleta		date
		,valor_venda		float
		,unidade_medida		varchar(255)
		,bandeira			varchar(255)

)
"""
# Out:
# '\nCREATE TABLE anp.preco_combustivel(\n\t\tregiao \t\t\t\tvarchar(255)\n\t\t,estado\t\t\t\tvarchar(255)\n\t\t,municipio\t\t\tvarchar(255)\n\t\t,revenda\t\t\tvarchar(255)\n\t\t,cnpj\t\t\t\tvarchar(255)\n\t\t,nome_rua\t\t\tvarchar(255)\t\n\t\t,numero_rua\t\t\tvarchar(255)\n\t\t,complemento\t\tvarchar(255)\n\t\t,bairro\t\t\t\tvarchar(255)\n\t\t,cep\t\t\t\tvarchar(255)\n\t\t,produto\t\t\tvarchar(255)\n\t\t,data_coleta\t\tdate\n\t\t,valor_venda\t\tfloat\n\t\t,unidade_medida\t\tvarchar(255)\n\t\t,bandeira\t\t\tvarchar(255)\n\n)\n'

# %% [markdown]
# Carga de dados no Banco! <br/>
# Utilizaremos o Knime<br/>
# <img src = 'knime.png'><br/>
# <img src = 'knime2.png'><br/>
# Para atender as nossas necessidades vamos construir desta forma.<br/>
# <img src = 'knime3.png'><br/>

# %% [markdown]
# 3 - Utilizar esses dados para as nossas análises <br/>

# %% [markdown]
# Instalando as bibliotecas

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\laiss\appdata\local\programs\python\python312\lib\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2 as ps

# %%
conn = ps.connect(dbname = "ANP",
                    user ='postgres',
                    password = 'Lun@1201',
                    host = 'localhost',
                    port = '5432' )

# %%
sql = """
SELECT * FROM "ANP".preco_combustivel
"""

# %%
df = sqlio.read_sql_query(sql, conn)
# Out:
# C:\Users\laiss\AppData\Local\Temp\ipykernel_42832\76855033.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(sql, conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = sqlio.read_sql_query(sql, conn)
#
# File c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)   2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2672 cur = self.con.cursor()
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#    2676 except Exception as exc:
#
# File c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\encodings\utf_8.py:15, in decode(input, errors)
#      11 ### Codec APIs
#      13 encode = codecs.utf_8_encode
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#   regiao estado  municipio                       revenda                cnpj  \
# 0     SE     SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA  49.051.667/0001-02
# 1     SE     SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA  49.051.667/0001-02
# 2     SE     SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA  49.051.667/0001-02
# 3     SE     SP  GUARULHOS      AUTO POSTO SAKAMOTO LTDA  49.051.667/0001-02
# 4     NE     BA   SALVADOR  PETROBRAS DISTRIBUIDORA S.A.  34.274.233/0015-08
#
#                    nome_rua numero_rua          complemento      bairro  \
# 0  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 1  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 2  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 3  RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 4         RUA EDISTIO PONDE        474                 None       STIEP
#
#          cep     produto data_coleta valor_venda unidade_medida  \
# 0  07178-580    GASOLINA  03/01/2020       4,399     R$ / litro
# 1  07178-580      ETANOL  03/01/2020       3,199     R$ / litro
# 2  07178-580  DIESEL S10  03/01/2020       3,899     R$ / litro
# 3  07178-580         GNV  03/01/2020       2,995       R$ / mÂ³
# 4  41770-395    GASOLINA  03/01/2020        4,69     R$ / litro
#
#                        bandeira
# 0  PETROBRAS DISTRIBUIDORA S.A.
# 1  PETROBRAS DISTRIBUIDORA S.A.
# 2  PETROBRAS DISTRIBUIDORA S.A.
# 3  PETROBRAS DISTRIBUIDORA S.A.
# 4  PETROBRAS DISTRIBUIDORA S.A.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4236875 entries, 0 to 4236874
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   regiao          object
#  1   estado          object
#  2   municipio       object
#  3   revenda         object
#  4   cnpj            object
#  5   nome_rua        object
#  6   numero_rua      object
#  7   complemento     object
#  8   bairro          object
#  9   cep             object
#  10  produto         object
#  11  data_coleta     object
#  12  valor_venda     object
#  13  unidade_medida  object
#  14  bandeira        object
# dtypes: object(15)
# memory usage: 484.9+ MB

# %%
df.shape
# Out:
# (4236875, 15)

# %%
df['data_coleta'] = pd.to_datetime(df['data_coleta'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4236875 entries, 0 to 4236874
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   regiao          object
#  1   estado          object
#  2   municipio       object
#  3   revenda         object
#  4   cnpj            object
#  5   nome_rua        object
#  6   numero_rua      object
#  7   complemento     object
#  8   bairro          object
#  9   cep             object
#  10  produto         object
#  11  data_coleta     datetime64[ns]
#  12  valor_venda     object
#  13  unidade_medida  object
#  14  bandeira        object
# dtypes: datetime64[ns](1), object(14)
# memory usage: 484.9+ MB

# %%
df.isnull().sum()

# %%
# Rerun this cell without interrupting it
df_anp = df[['data_coleta', 'regiao', 'estado', 'municipio', 'bandeira','produto', 'valor_venda']]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_49712\4259817233.py in ?()
# ----> 1 df_anp = df[['data_coleta', 'regiao', 'estado', 'municipio', 'bandeira','produto', 'valor_venda']]
#
# c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4113
#    4114         if isinstance(indexer, slice):
#    4115             return self._slice(indexer, axis=1)
#    4116
# -> 4117         data = self._take_with_is_copy(indexer, axis=1)
#    4118
#    4119         if is_single_key:
#    4120             # What does looking for a single key in a non-unique index return?
#
# c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, indices, axis)
#    4151         See the docstring of `take` for full explanation of the parameters.
#    4152         """
#    4153         result = self.take(indices=indices, axis=axis)
#    4154         # Maybe set copy if we didn't actually change the index.
# -> 4155         if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#    4156             result._set_is_copy(self)
#    4157         return result
#
# c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, axis)
#     586     @final
#     587     def _get_axis(self, axis: Axis) -> Index:
# --> 588         axis_number = self._get_axis_number(axis)
#     589         assert axis_number in {0, 1}
#     590         return self.index if axis_number == 0 else self.columns
#
# c:\Users\laiss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
# --> 572     @final
#     573     @classmethod
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#
# KeyboardInterrupt:

# %%
df_anp.head()

# %%
df_anp['ano'] = df_anp['data_coleta'].dt.year
df_anp['mes'] = df_anp['data_coleta'].dt.month

# %%
df_anp.head()

# %%
df_anp.describe().round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_anp.describe().round(2)
#
# NameError: name 'df_anp' is not defined

# %%
#Visualizando os valores únicos
print(f'Os produtos conecializados{df_anp.produto.unique()}')

# %%
#Visualizando os valores únicos
print(f'Os anos da Base: {df_anp.ano.unique()}')

# %%
df_anp_valor = df_anp[['ano', 'produto', 'valor_venda']]

# %%
df_anp_valor.groupby(['produto','ano']).agg(['min', 'max', 'mean']).round(2)

# %%
df_anp_valor_estado = df_anp[['ano', 'produto', 'estado','valor_venda']]

# %%
df_anp_valor_estado.groupby(['produto','ano','estado']).agg(['min', 'max', 'mean']).round(2)

# %%
df_anp_bandeira = df_anp[['ano','bandeira','produto']]

# %%
df_anp_bandeira.groupby(['ano','produto']).bandeira.nunique()

# %%
df_anp_bandeira_estado = df_anp[['ano','bandeira','produto', 'estado']]

# %%
df_anp_bandeira_estado.groupby(['ano','produto','estado']).bandeira.nunique()
